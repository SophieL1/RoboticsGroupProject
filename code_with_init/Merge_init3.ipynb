# %%
import cv2
from cv2 import aruco
import numpy as np
from matplotlib import pyplot as plt
import time

from init import init
#fonction Sophie
#from findPath import findPath

#fonction Liandro
from camera import live_cam

# %%
def main():
    my_coordinates, expanded_obs, cam, corner_coordinates = init()
    print("my_coordinates : ", my_coordinates)
    print("my_coordinates 0 : ", my_coordinates[0])
    while True:
        live_cam(cam, corner_coordinates, my_coordinates, expanded_obs)
        # Break the loop if the 'Esc' key is pressed
        if cv2.waitKey(100) == 27:  # ASCII code for 'Esc' key
            cam.release()
            cv2.destroyAllWindows()
            break
        
if __name__ == "__main__":
    main()
# Out:
# Impossible to find the 4 corners !!
# corner_coordinates OK :  [[109, 19], [555, 16], [602, 458], [67, 456]]
# position goal OK:  [727, 253]
# pos_goal :  [727, 253]
# pos_obstacle :  [[[669, 584], [615, 610], [591, 651], [610, 677], [663, 652], [688, 609]], [[464, 452], [422, 519], [422, 602], [465, 582], [490, 487]], [[207, 182], [41, 194], [41, 239], [210, 230]], [[399, 46], [392, 87], [492, 133], [395, 59], [512, 55]]]
# pos_thymio :  [150, 650, -86.31]
# Obstacle  0
# [(572.4706728209293, 563.8845320620488), (519.3459894840034, 654.639199429297), (590.7881752622882, 752.4021904943182), (705.4852038238029, 698.2998185313395), (759.9859783153648, 604.5584864058532), (687.120447908101, 508.68278850155866)]
# Obstacle  1
# [(362.0, 501.7486958658902), (362.0, 696.0794736821175), (515.8533759214325, 624.5197639512186), (555.3651339802707, 474.37508332763366), (459.8015977094564, 345.7318614246145)]
# Obstacle  2
# ...
